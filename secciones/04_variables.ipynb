# %% [markdown]
# # Variables
# > Davd Quintanar Pérez

# %% [markdown]
# ## str

# %%
hola_mundo = "Hola Mundo!"

# %%
hola_mundo = 'Hola Mundo!'

# %%
hola_mundo = """Hola Mundo!"""

# %%
hola_mundo = '''Hola Mundo!'''

# %% [markdown]
# ## int

# %%
edad = 26

# %% [markdown]
# ## float

# %%
importe = 100000000000000000000.00

# %% [markdown]
# ## complex

# %%
coordenadas = 0 + 0j

# %% [markdown]
# ## bool

# %%
es_mayor = True

# %%
es_interesante = False

# %% [markdown]
# ## bytes

# %%
b_hola_mundo = b"Hola Mundo!"

# %% [markdown]
# ## list

# %%
estrellas = [0, 1, 2, 4, 5]

# %% [markdown]
# ## tuple

# %%
registros = (0, 1, 2)

# %% [markdown]
# ## range

# %%
rango_de_alumnos = range(5)

# %% [markdown]
# ## dict

# %%
compras_amazon = {0: "echo dot", 1: "echo show", 2: "kindle"}

# %% [markdown]
# ## set

# %%
cursos_bluetab = {"Scala y spark (teoría)","Scala y spark (práctica)", "Python"}

# %% [markdown]
# <hr style="height: 2px; background-color: blue;">

# %% [markdown]
# ## Cambio de tipo de dato

# %%
print(
    """
    variable = str(dato)
    variable = int(dato)
    variable = float(dato)
    variable = complex(dato)
    variable = bool(dato)
    variable = bytes(dato)
    variable = list(dato)
    variable = dict(dato)
    variable = set(dato)
    """
    )

# %% [markdown]
# <hr style="height: 2px; background-color: blue;">

# %% [markdown]
# ## Buenas practicas
